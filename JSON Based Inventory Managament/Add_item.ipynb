# %%
import json

fd = open("Records.json",'r')
r = fd.read()
fd.close()
Record = json.loads(r)

# %%
Record
# Out:
# {'1001': {'Name': 'Fish',
#   'Quantity': 30,
#   'Price': 10,
#   'Discount': '4%',
#   'MRP': 50},
#  '1000': {'Name': 'Cake',
#   'Price': 800,
#   'Quantity': 100,
#   'Discount': '10%',
#   'MRP': 900},
#  '1003': {'Name': 'Drink',
#   'Price': 85,
#   'Quantity': 100,
#   'Discount': '15%',
#   'MRP': 100},
#  '1004': {'Name': 'Candy',
#   'Price': 5,
#   'Quantity': 1000,
#   'Discount': '0%',
#   'MRP': 10},
#  '1005': {'Name': 'Pen',
#   'Price': 20,
#   'Quantity': 100,
#   'Discount': '25%',
#   'MRP': 30},
#  '1006': {'Name': 'Phone',
#   'Price': 50000,
#   'Quantity': 10,
#   'Discount': '20%',
#   'MRP': 60000},
#  '1007': {'Name': 'Mic',
#   'Price': 1500,
#   'Quantity': 0,
#   'Discount': '10%',
#   'MRP': 1700},
#  '1008': {'Name': 'Case',
#   'Price': 599,
#   'Quantity': 5,
#   'Discount': '7%',
#   'MRP': 700},
#  '1009': {'Name': 'Keyboard',
#   'Price': 1999,
#   'Quantity': 10,
#   'Discount': '17%',
#   'MRP': 2200},
#  '1010': {'Name': 'Book',
#   'Price': 500,
#   'Quantity': 30,
#   'Discount': '2%',
#   'MRP': 600},
#  '1011': {'Name': 'Calculator',
#   'Price': 800,
#   'Quantity': 20,
#   'Discount': '30%',
#   'MRP': 1200},
#  '1012': {'Name': 'Laptop',
#   'Price': 80000,
#   'Quantity': 10,
#   'Discount': '30%',
#   'MRP': 100000},
#  '1013': {'Name': 'Speakers',
#   'Price': 8000,
#   'Quantity': 10,
#   'Discount': '10%',
#   'MRP': 9000},
#  '1014': {'Name': 'Table',
#   'Price': 5000,
#   'Quantity': 15,
#   'Discount': '20%',
#   'MRP': 6700},
#  '1015': {'Name': 'Watch',
#   'Price': 2900,
#   'Quantity': 20,
#   'Discount': '30%',
#   'MRP': 3200},
#  '1016': {'Name': 'Shoe',
#   'Price': 3000,
#   'Quantity': 40,
#   'Discount': '15%',
#   'MRP': 3200},
#  '1017': {'Name': 'Bag',
#   'Price': 2200,
#   'Quantity': 0,
#   'Discount': '15%',
#   'MRP': 2400},
#  '1018': {'Name': 'Headset',
#   'Price': 1700,
#   'Quantity': 50,
#   'Discount': '30%',
#   'MRP': 1900},
#  '1019': {'Name': 'Charger',
#   'Price': 400,
#   'Quantity': 30,
#   'Discount': '10%',
#   'MRP': 500},
#  '1020': {'Name': 'A/C',
#   'Price': 30000,
#   'Quantity': 20,
#   'Discount': '10%',
#   'MRP': 33000},
#  '1021': {'Name': 'Hammer',
#   'Price': 1000,
#   'Quantity': 10,
#   'Discount': '0%',
#   'MRP': 1100},
#  '1022': {'Name': 'Chair',
#   'Price': 800,
#   'Quantity': 10,
#   'Discount': '10%',
#   'MRP': 1000},
#  '1023': {'Name': 'Table',
#   'Price': 1800,
#   'Quantity': 50,
#   'Discount': '20%',
#   'MRP': 2000},
#  '1024': {'Name': 'Clock',
#   'Price': 300,
#   'Quantity': 20,
#   'Discount': '3%',
#   'MRP': 400},
#  '1025': {'Name': 'Pillow',
#   'Price': 600,
#   'Quantity': 0,
#   'Discount': '0%',
#   'MRP': 600},
#  '1026': {'Name': 'Sofa',
#   'Price': 5000,
#   'Quantity': 5,
#   'Discount': '10%',
#   'MRP': 5500},
#  '1027': {'Name': 'Ice creame',
#   'Price': 80,
#   'Quantity': 20,
#   'Discount': '0%',
#   'MRP': 100},
#  '1028': {'Name': 'Camera',
#   'Price': 4000,
#   'Quantity': 15,
#   'Discount': '13%',
#   'MRP': 4100},
#  '1029': {'Name': 'Tablet',
#   'Price': 6000,
#   'Quantity': 17,
#   'Discount': '10%',
#   'MRP': 6200},
#  '1030': {'Name': 'Fan',
#   'Price': 700,
#   'Quantity': 17,
#   'Discount': '4%',
#   'MRP': 757}}

# %% [markdown]
# # Adding Item to Inventory

# %%
Product_id = str(input("Enter product id:"))
Name = input("Enter name:")
Price = int(input("Enter price:"))
Quantity = int(input("Enter quantity:"))
Discount = int(input("Enter Discount: "))
MRP= int(input("Enter MRP:"))
Discount = str(Discount)+"%"
Record[Product_id] = {'Name': Name, 'Price': Price, 'Quantity': Quantity,'Discount':Discount,'MRP':MRP }

js = json.dumps(Record)

fd = open("Record.json",'w')
fd.write(js)
fd.close()
# Out:
# Enter product id:1025
# Enter name:Pillow
# Enter price:600
# Enter quantity:0
# Enter Discount: 0
# Enter MRP:600

# %%
Record
# Out:
# {'1001': {'Name': 'Fish',
#   'Quantity': 30,
#   'Price': 10,
#   'Discount': '4%',
#   'MRP': 50},
#  '1000': {'Name': 'Cake',
#   'Price': 800,
#   'Quantity': 100,
#   'Discount': '10%',
#   'MRP': 900},
#  '1003': {'Name': 'Drink',
#   'Price': 85,
#   'Quantity': 100,
#   'Discount': '15%',
#   'MRP': 100},
#  '1004': {'Name': 'Candy',
#   'Price': 5,
#   'Quantity': 1000,
#   'Discount': '0%',
#   'MRP': 10},
#  '1005': {'Name': 'Pen',
#   'Price': 20,
#   'Quantity': 100,
#   'Discount': '25%',
#   'MRP': 30},
#  '1006': {'Name': 'Phone',
#   'Price': 50000,
#   'Quantity': 10,
#   'Discount': '20%',
#   'MRP': 60000},
#  '1007': {'Name': 'Mic',
#   'Price': 1500,
#   'Quantity': 0,
#   'Discount': '10%',
#   'MRP': 1700},
#  '1008': {'Name': 'Case',
#   'Price': 599,
#   'Quantity': 5,
#   'Discount': '7%',
#   'MRP': 700},
#  '1009': {'Name': 'Keyboard',
#   'Price': 1999,
#   'Quantity': 10,
#   'Discount': '17%',
#   'MRP': 2200},
#  '1010': {'Name': 'Book',
#   'Price': 500,
#   'Quantity': 30,
#   'Discount': '2%',
#   'MRP': 600},
#  '1011': {'Name': 'Calculator',
#   'Price': 800,
#   'Quantity': 20,
#   'Discount': '30%',
#   'MRP': 1200},
#  '1012': {'Name': 'Laptop',
#   'Price': 80000,
#   'Quantity': 10,
#   'Discount': '30%',
#   'MRP': 100000},
#  '1013': {'Name': 'Speakers',
#   'Price': 8000,
#   'Quantity': 10,
#   'Discount': '10%',
#   'MRP': 9000},
#  '1014': {'Name': 'Table',
#   'Price': 5000,
#   'Quantity': 15,
#   'Discount': '20%',
#   'MRP': 6700},
#  '1015': {'Name': 'Watch',
#   'Price': 2900,
#   'Quantity': 20,
#   'Discount': '30%',
#   'MRP': 3200},
#  '1016': {'Name': 'Shoe',
#   'Price': 3000,
#   'Quantity': 40,
#   'Discount': '15%',
#   'MRP': 3200},
#  '1017': {'Name': 'Bag',
#   'Price': 2200,
#   'Quantity': 0,
#   'Discount': '15%',
#   'MRP': 2400},
#  '1018': {'Name': 'Headset',
#   'Price': 1700,
#   'Quantity': 50,
#   'Discount': '30%',
#   'MRP': 1900},
#  '1019': {'Name': 'Charger',
#   'Price': 400,
#   'Quantity': 30,
#   'Discount': '10%',
#   'MRP': 500},
#  '1020': {'Name': 'A/C',
#   'Price': 30000,
#   'Quantity': 20,
#   'Discount': '10%',
#   'MRP': 33000},
#  '1021': {'Name': 'Hammer',
#   'Price': 1000,
#   'Quantity': 10,
#   'Discount': '0%',
#   'MRP': 1100},
#  '1022': {'Name': 'Chair',
#   'Price': 800,
#   'Quantity': 10,
#   'Discount': '10%',
#   'MRP': 1000},
#  '1023': {'Name': 'Table',
#   'Price': 1800,
#   'Quantity': 50,
#   'Discount': '20%',
#   'MRP': 2000},
#  '1024': {'Name': 'Clock',
#   'Price': 300,
#   'Quantity': 20,
#   'Discount': '3%',
#   'MRP': 400},
#  '1025': {'Name': 'Pillow',
#   'Price': 600,
#   'Quantity': 0,
#   'Discount': '0%',
#   'MRP': 600},
#  '1026': {'Name': 'Sofa',
#   'Price': 5000,
#   'Quantity': 5,
#   'Discount': '10%',
#   'MRP': 5500},
#  '1027': {'Name': 'Ice creame',
#   'Price': 80,
#   'Quantity': 20,
#   'Discount': '0%',
#   'MRP': 100},
#  '1028': {'Name': 'Camera',
#   'Price': 4000,
#   'Quantity': 15,
#   'Discount': '13%',
#   'MRP': 4100},
#  '1029': {'Name': 'Tablet',
#   'Price': 6000,
#   'Quantity': 17,
#   'Discount': '10%',
#   'MRP': 6200},
#  '1030': {'Name': 'Fan',
#   'Price': 700,
#   'Quantity': 17,
#   'Discount': '4%',
#   'MRP': 757}}
